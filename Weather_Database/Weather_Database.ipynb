# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 773

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]        

            # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country})


    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | souillac
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | bjornevatn
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | alta floresta
# Processing Record 6 of Set 1 | kalmunai
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | henties bay
# Processing Record 9 of Set 1 | korla
# Processing Record 10 of Set 1 | hofn
# Processing Record 11 of Set 1 | castro
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | salacgriva
# Processing Record 14 of Set 1 | kashi
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | mahebourg
# Processing Record 18 of Set 1 | sao joao da barra
# Processing Record 19 of Set 1 | alcantara
# Processing Record 20 of Set 1 | usinsk
# Processing Record 21 of Set 1 | narsaq
# Processing Record 22 of Set 1 | talara
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 1 | hun
# Processing Record 27 of Set 1 | andros town
# Processing Record 28 of Set 1 | clyde river
# Processing Record 29 of Set 1 | lebu
# Processing Record 30 of Set 1 | bandarbeyla
# Processing Record 31 of Set 1 | san andres
# Processing Record 32 of Set 1 | ilulissat
# Processing Record 33 of Set 1 | qandahar
# City not found. Skipping...
# Processing Record 34 of Set 1 | salalah
# Processing Record 35 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 1 | daimiel
# Processing Record 37 of Set 1 | tessalit
# Processing Record 38 of Set 1 | bristol
# Processing Record 39 of Set 1 | adrar
# Processing Record 40 of Set 1 | ombessa
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | nefteyugansk
# Processing Record 44 of Set 1 | krasnyy yar
# Processing Record 45 of Set 1 | thunder bay
# Processing Record 46 of Set 1 | atar
# Processing Record 47 of Set 1 | georgetown
# Processing Record 48 of Set 1 | cidreira
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | torbay
# Processing Record 1 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | marsa matruh
# Processing Record 4 of Set 2 | chuy
# Processing Record 5 of Set 2 | cermik
# Processing Record 6 of Set 2 | guican
# Processing Record 7 of Set 2 | shubarkuduk
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | abu samrah
# Processing Record 10 of Set 2 | mehamn
# Processing Record 11 of Set 2 | tazovskiy
# Processing Record 12 of Set 2 | merta
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | zhezkazgan
# Processing Record 15 of Set 2 | tasiilaq
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | dabeiba
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | vallenar
# Processing Record 20 of Set 2 | puerto leguizamo
# Processing Record 21 of Set 2 | vila franca do campo
# Processing Record 22 of Set 2 | kerki
# City not found. Skipping...
# Processing Record 23 of Set 2 | gorom-gorom
# Processing Record 24 of Set 2 | kadoshkino
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | roald
# Processing Record 27 of Set 2 | changji
# Processing Record 28 of Set 2 | beyneu
# Processing Record 29 of Set 2 | hambantota
# Processing Record 30 of Set 2 | berdychiv
# Processing Record 31 of Set 2 | manicore
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | rabo de peixe
# Processing Record 34 of Set 2 | salinas
# Processing Record 35 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 2 | goure
# Processing Record 37 of Set 2 | kamina
# Processing Record 38 of Set 2 | muros
# Processing Record 39 of Set 2 | zhob
# Processing Record 40 of Set 2 | corrales
# Processing Record 41 of Set 2 | nuuk
# Processing Record 42 of Set 2 | kasongo-lunda
# Processing Record 43 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 2 | mount darwin
# Processing Record 45 of Set 2 | longyearbyen
# Processing Record 46 of Set 2 | takoradi
# Processing Record 47 of Set 2 | puerto carreno
# Processing Record 48 of Set 2 | lagoa
# Processing Record 49 of Set 2 | bambous virieux
# Processing Record 50 of Set 2 | saint-philippe
# Processing Record 1 of Set 3 | kavaratti
# Processing Record 2 of Set 3 | montague
# Processing Record 3 of Set 3 | touros
# Processing Record 4 of Set 3 | roslyakovo
# Processing Record 5 of Set 3 | slavsk
# Processing Record 6 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 7 of Set 3 | lahij
# Processing Record 8 of Set 3 | saint-georges
# Processing Record 9 of Set 3 | dingle
# Processing Record 10 of Set 3 | black river
# Processing Record 11 of Set 3 | maniitsoq
# Processing Record 12 of Set 3 | quatre cocos
# Processing Record 13 of Set 3 | bequimao
# Processing Record 14 of Set 3 | bathsheba
# Processing Record 15 of Set 3 | thompson
# Processing Record 16 of Set 3 | plettenberg bay
# Processing Record 17 of Set 3 | baghdad
# Processing Record 18 of Set 3 | locri
# Processing Record 19 of Set 3 | berlevag
# Processing Record 20 of Set 3 | villamartin
# Processing Record 21 of Set 3 | jintur
# Processing Record 22 of Set 3 | avallon
# Processing Record 23 of Set 3 | port alfred
# Processing Record 24 of Set 3 | rawson
# Processing Record 25 of Set 3 | gunjur
# Processing Record 26 of Set 3 | husavik
# Processing Record 27 of Set 3 | mount pleasant
# Processing Record 28 of Set 3 | maragogi
# Processing Record 29 of Set 3 | hamilton
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | satao
# Processing Record 32 of Set 3 | trincomalee
# Processing Record 33 of Set 3 | waraseoni
# Processing Record 34 of Set 3 | minab
# Processing Record 35 of Set 3 | quimperle
# Processing Record 36 of Set 3 | scarborough
# Processing Record 37 of Set 3 | kulhudhuffushi
# Processing Record 38 of Set 3 | port-cartier
# Processing Record 39 of Set 3 | camacha
# Processing Record 40 of Set 3 | valga
# Processing Record 41 of Set 3 | nanortalik
# Processing Record 42 of Set 3 | caravelas
# Processing Record 43 of Set 3 | aranzazu
# Processing Record 44 of Set 3 | yenagoa
# Processing Record 45 of Set 3 | silale
# Processing Record 46 of Set 3 | sisimiut
# Processing Record 47 of Set 3 | kruisfontein
# Processing Record 48 of Set 3 | zamora
# Processing Record 49 of Set 3 | coquimbo
# Processing Record 50 of Set 3 | balykshi
# Processing Record 1 of Set 4 | grindavik
# Processing Record 2 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 3 of Set 4 | hermon
# Processing Record 4 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 4 | gat
# Processing Record 6 of Set 4 | arlit
# Processing Record 7 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 4 | poshtove
# Processing Record 9 of Set 4 | nova olimpia
# Processing Record 10 of Set 4 | raudeberg
# Processing Record 11 of Set 4 | san cristobal
# Processing Record 12 of Set 4 | boa vista
# Processing Record 13 of Set 4 | verkhnyaya inta
# Processing Record 14 of Set 4 | lamu
# Processing Record 15 of Set 4 | qaqortoq
# Processing Record 16 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 4 | ilhabela
# Processing Record 18 of Set 4 | vardo
# Processing Record 19 of Set 4 | mitsamiouli
# Processing Record 20 of Set 4 | sabzevar
# Processing Record 21 of Set 4 | gamba
# Processing Record 22 of Set 4 | kukushtan
# Processing Record 23 of Set 4 | awjilah
# Processing Record 24 of Set 4 | turukhansk
# Processing Record 25 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 4 | yar-sale
# Processing Record 27 of Set 4 | pozo colorado
# Processing Record 28 of Set 4 | ust-tsilma
# Processing Record 29 of Set 4 | choma
# Processing Record 30 of Set 4 | maldonado
# Processing Record 31 of Set 4 | sakskobing
# Processing Record 32 of Set 4 | saint anthony
# Processing Record 33 of Set 4 | ocumare del tuy
# Processing Record 34 of Set 4 | mayumba
# Processing Record 35 of Set 4 | rundu
# Processing Record 36 of Set 4 | camocim
# Processing Record 37 of Set 4 | praia da vitoria
# Processing Record 38 of Set 4 | anta
# Processing Record 39 of Set 4 | namibe
# Processing Record 40 of Set 4 | ancud
# Processing Record 41 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 4 | huarmey
# Processing Record 43 of Set 4 | luderitz
# Processing Record 44 of Set 4 | jatai
# Processing Record 45 of Set 4 | muzhi
# Processing Record 46 of Set 4 | brokopondo
# Processing Record 47 of Set 4 | itarema
# Processing Record 48 of Set 4 | opuwo
# Processing Record 49 of Set 4 | karlskrona
# Processing Record 50 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 5 | ballina
# Processing Record 2 of Set 5 | sept-iles
# Processing Record 3 of Set 5 | jaciara
# Processing Record 4 of Set 5 | ramanuj ganj
# Processing Record 5 of Set 5 | qaanaaq
# Processing Record 6 of Set 5 | la primavera
# Processing Record 7 of Set 5 | santa isabel do rio negro
# Processing Record 8 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 9 of Set 5 | surt
# Processing Record 10 of Set 5 | rocha
# Processing Record 11 of Set 5 | kranea elassonos
# Processing Record 12 of Set 5 | ostrovnoy
# Processing Record 13 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 5 | malpe
# Processing Record 15 of Set 5 | rajaldesar
# Processing Record 16 of Set 5 | iqaluit
# Processing Record 17 of Set 5 | kitovo
# Processing Record 18 of Set 5 | manyana
# Processing Record 19 of Set 5 | bull savanna
# Processing Record 20 of Set 5 | san ramon
# Processing Record 21 of Set 5 | camabatela
# Processing Record 22 of Set 5 | codrington
# Processing Record 23 of Set 5 | chimbote
# Processing Record 24 of Set 5 | kibaya
# Processing Record 25 of Set 5 | george town
# Processing Record 26 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 5 | meridian
# Processing Record 28 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 29 of Set 5 | villa carlos paz
# Processing Record 30 of Set 5 | paso de carrasco
# Processing Record 31 of Set 5 | geraldton
# Processing Record 32 of Set 5 | goya
# Processing Record 33 of Set 5 | victoria
# Processing Record 34 of Set 5 | bababe
# City not found. Skipping...
# Processing Record 35 of Set 5 | balboa
# Processing Record 36 of Set 5 | iralaya
# Processing Record 37 of Set 5 | salinopolis
# Processing Record 38 of Set 5 | terrace bay
# Processing Record 39 of Set 5 | coihaique
# Processing Record 40 of Set 5 | shemonaikha
# Processing Record 41 of Set 5 | bulaevo
# Processing Record 42 of Set 5 | rio grande
# Processing Record 43 of Set 5 | kollo
# Processing Record 44 of Set 5 | korem
# Processing Record 45 of Set 5 | saint andrews
# Processing Record 46 of Set 5 | mbekenyera
# Processing Record 47 of Set 5 | birao
# Processing Record 48 of Set 5 | tucuman
# Processing Record 49 of Set 5 | talnakh
# Processing Record 50 of Set 5 | sorland
# Processing Record 1 of Set 6 | ribeira brava
# Processing Record 2 of Set 6 | ruhengeri
# Processing Record 3 of Set 6 | klaksvik
# Processing Record 4 of Set 6 | marawi
# Processing Record 5 of Set 6 | leshukonskoye
# Processing Record 6 of Set 6 | sembe
# Processing Record 7 of Set 6 | matara
# Processing Record 8 of Set 6 | shelburne
# Processing Record 9 of Set 6 | goderich
# Processing Record 10 of Set 6 | mocuba
# Processing Record 11 of Set 6 | lima
# Processing Record 12 of Set 6 | nouakchott
# Processing Record 13 of Set 6 | lasa
# Processing Record 14 of Set 6 | point fortin
# Processing Record 15 of Set 6 | makat
# Processing Record 16 of Set 6 | alta
# Processing Record 17 of Set 6 | savona
# Processing Record 18 of Set 6 | bosobolo
# Processing Record 19 of Set 6 | muncie
# Processing Record 20 of Set 6 | chamba
# Processing Record 21 of Set 6 | santa cruz de la palma
# Processing Record 22 of Set 6 | richards bay
# Processing Record 23 of Set 6 | tsiroanomandidy
# Processing Record 24 of Set 6 | niquero
# Processing Record 25 of Set 6 | luwingu
# Processing Record 26 of Set 6 | bubaque
# Processing Record 27 of Set 6 | orito
# Processing Record 28 of Set 6 | garowe
# Processing Record 29 of Set 6 | el alto
# Processing Record 30 of Set 6 | paita
# Processing Record 31 of Set 6 | sinnamary
# Processing Record 32 of Set 6 | kyshtovka
# Processing Record 33 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 6 | gazojak
# Processing Record 35 of Set 6 | kukes
# Processing Record 36 of Set 6 | vila velha
# Processing Record 37 of Set 6 | rokytne
# Processing Record 38 of Set 6 | godhra
# Processing Record 39 of Set 6 | sohag
# Processing Record 40 of Set 6 | humberto de campos
# Processing Record 41 of Set 6 | najran
# Processing Record 42 of Set 6 | los llanos de aridane
# Processing Record 43 of Set 6 | hare bay
# Processing Record 44 of Set 6 | villazon
# Processing Record 45 of Set 6 | ambatofinandrahana
# Processing Record 46 of Set 6 | greeneville
# Processing Record 47 of Set 6 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 48 of Set 6 | sumbawanga
# Processing Record 49 of Set 6 | mantua
# Processing Record 50 of Set 6 | axim
# Processing Record 1 of Set 7 | road town
# Processing Record 2 of Set 7 | morant bay
# Processing Record 3 of Set 7 | bandundu
# Processing Record 4 of Set 7 | katesh
# Processing Record 5 of Set 7 | gloucester
# Processing Record 6 of Set 7 | chirongui
# Processing Record 7 of Set 7 | saint-francois
# Processing Record 8 of Set 7 | sosua
# Processing Record 9 of Set 7 | mulchen
# Processing Record 10 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 11 of Set 7 | presidencia roque saenz pena
# Processing Record 12 of Set 7 | mangrol
# Processing Record 13 of Set 7 | oistins
# Processing Record 14 of Set 7 | catamarca
# Processing Record 15 of Set 7 | luxor
# Processing Record 16 of Set 7 | vendychany
# Processing Record 17 of Set 7 | jitauna
# Processing Record 18 of Set 7 | giyani
# Processing Record 19 of Set 7 | porto santo
# Processing Record 20 of Set 7 | bom jardim
# Processing Record 21 of Set 7 | kirkwall
# Processing Record 22 of Set 7 | surami
# Processing Record 23 of Set 7 | heinola
# Processing Record 24 of Set 7 | banda aceh
# Processing Record 25 of Set 7 | bhinga
# Processing Record 26 of Set 7 | sialkot
# Processing Record 27 of Set 7 | faya
# Processing Record 28 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 29 of Set 7 | usogorsk
# Processing Record 30 of Set 7 | tadepallegudem
# Processing Record 31 of Set 7 | imaculada
# Processing Record 32 of Set 7 | nantucket
# Processing Record 33 of Set 7 | dobrun
# Processing Record 34 of Set 7 | valjala
# City not found. Skipping...
# Processing Record 35 of Set 7 | antalaha
# Processing Record 36 of Set 7 | west bay
# Processing Record 37 of Set 7 | ponta delgada
# Processing Record 38 of Set 7 | pisco
# Processing Record 39 of Set 7 | inhambane
# Processing Record 40 of Set 7 | praia
# Processing Record 41 of Set 7 | borba
# Processing Record 42 of Set 7 | ustye
# Processing Record 43 of Set 7 | kaffrine
# Processing Record 44 of Set 7 | cervo
# Processing Record 45 of Set 7 | danville
# Processing Record 46 of Set 7 | lerwick
# Processing Record 47 of Set 7 | kintampo
# Processing Record 48 of Set 7 | peyima
# Processing Record 49 of Set 7 | itaueira
# Processing Record 50 of Set 7 | curuguaty
# Processing Record 1 of Set 8 | beroroha
# Processing Record 2 of Set 8 | aquiraz
# Processing Record 3 of Set 8 | masindi
# Processing Record 4 of Set 8 | maine-soroa
# Processing Record 5 of Set 8 | la malbaie
# Processing Record 6 of Set 8 | sao felix do xingu
# Processing Record 7 of Set 8 | paamiut
# Processing Record 8 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 9 of Set 8 | nola
# Processing Record 10 of Set 8 | bengkulu
# Processing Record 11 of Set 8 | karasuk
# Processing Record 12 of Set 8 | san rafael del sur
# Processing Record 13 of Set 8 | stamsund
# City not found. Skipping...
# Processing Record 14 of Set 8 | velsk
# Processing Record 15 of Set 8 | bingerville
# Processing Record 16 of Set 8 | nikolsk
# Processing Record 17 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 18 of Set 8 | kedrovyy
# Processing Record 19 of Set 8 | pinega
# Processing Record 20 of Set 8 | saint-pierre
# Processing Record 21 of Set 8 | zemio
# Processing Record 22 of Set 8 | buraydah
# Processing Record 23 of Set 8 | bereda
# Processing Record 24 of Set 8 | sainte-martine
# Processing Record 25 of Set 8 | senanga
# Processing Record 26 of Set 8 | grand gaube
# Processing Record 27 of Set 8 | bonavista
# Processing Record 28 of Set 8 | valparaiso
# Processing Record 29 of Set 8 | quelimane
# Processing Record 30 of Set 8 | qandala
# Processing Record 31 of Set 8 | taltal
# Processing Record 32 of Set 8 | sao filipe
# Processing Record 33 of Set 8 | iskateley
# Processing Record 34 of Set 8 | beloha
# Processing Record 35 of Set 8 | albany
# Processing Record 36 of Set 8 | jalu
# Processing Record 37 of Set 8 | wamba
# Processing Record 38 of Set 8 | palanga
# Processing Record 39 of Set 8 | chambersburg
# Processing Record 40 of Set 8 | diffa
# Processing Record 41 of Set 8 | saint-denis
# Processing Record 42 of Set 8 | vigrestad
# Processing Record 43 of Set 8 | laguna
# Processing Record 44 of Set 8 | tarko-sale
# Processing Record 45 of Set 8 | santa sofia
# Processing Record 46 of Set 8 | lipin bor
# Processing Record 47 of Set 8 | mgandu
# Processing Record 48 of Set 8 | caconda
# Processing Record 49 of Set 8 | jawhar
# Processing Record 50 of Set 8 | linhares
# Processing Record 1 of Set 9 | tutoia
# Processing Record 2 of Set 9 | omboue
# Processing Record 3 of Set 9 | inta
# Processing Record 4 of Set 9 | saint stephen
# Processing Record 5 of Set 9 | owando
# Processing Record 6 of Set 9 | micheweni
# Processing Record 7 of Set 9 | aleksandrovka
# Processing Record 8 of Set 9 | riyadh
# Processing Record 9 of Set 9 | meulaboh
# Processing Record 10 of Set 9 | mezen
# Processing Record 11 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 12 of Set 9 | dabola
# Processing Record 13 of Set 9 | valdivia
# Processing Record 14 of Set 9 | borama
# City not found. Skipping...
# Processing Record 15 of Set 9 | tibiri
# Processing Record 16 of Set 9 | kletnya
# Processing Record 17 of Set 9 | hit
# Processing Record 18 of Set 9 | santa cruz
# Processing Record 19 of Set 9 | abu dhabi
# Processing Record 20 of Set 9 | ocean city
# Processing Record 21 of Set 9 | revda
# Processing Record 22 of Set 9 | marabba
# Processing Record 23 of Set 9 | goundam
# Processing Record 24 of Set 9 | macapa
# Processing Record 25 of Set 9 | margate
# Processing Record 26 of Set 9 | manacapuru
# Processing Record 27 of Set 9 | brigantine
# Processing Record 28 of Set 9 | tucurui
# Processing Record 29 of Set 9 | sal rei
# Processing Record 30 of Set 9 | tarauaca
# Processing Record 31 of Set 9 | puerto suarez
# Processing Record 32 of Set 9 | oxapampa
# Processing Record 33 of Set 9 | kerman
# Processing Record 34 of Set 9 | derbent
# Processing Record 35 of Set 9 | olafsvik
# Processing Record 36 of Set 9 | agadez
# Processing Record 37 of Set 9 | saraland
# Processing Record 38 of Set 9 | waddan
# Processing Record 39 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 40 of Set 9 | lenoir city
# Processing Record 41 of Set 9 | garissa
# Processing Record 42 of Set 9 | myrtle beach
# Processing Record 43 of Set 9 | kisangani
# Processing Record 44 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 9 | saldanha
# Processing Record 46 of Set 9 | hamden
# Processing Record 47 of Set 9 | vyritsa
# Processing Record 48 of Set 9 | le port
# Processing Record 49 of Set 9 | jumla
# Processing Record 50 of Set 9 | ugoofaaru
# Processing Record 1 of Set 10 | peniche
# Processing Record 2 of Set 10 | barabinsk
# Processing Record 3 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 4 of Set 10 | tabou
# Processing Record 5 of Set 10 | shakhrinau
# City not found. Skipping...
# Processing Record 6 of Set 10 | marhaura
# Processing Record 7 of Set 10 | hualmay
# Processing Record 8 of Set 10 | becerril
# Processing Record 9 of Set 10 | amparafaravola
# Processing Record 10 of Set 10 | sur
# Processing Record 11 of Set 10 | dwarka
# Processing Record 12 of Set 10 | sovetsk
# Processing Record 13 of Set 10 | xuddur
# Processing Record 14 of Set 10 | saint george
# Processing Record 15 of Set 10 | kohlu
# Processing Record 16 of Set 10 | tornio
# Processing Record 17 of Set 10 | turbat
# Processing Record 18 of Set 10 | muisne
# Processing Record 19 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 20 of Set 10 | pitkyaranta
# Processing Record 21 of Set 10 | jasper
# Processing Record 22 of Set 10 | mecca
# Processing Record 23 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 24 of Set 10 | walvis bay
# Processing Record 25 of Set 10 | elizabethton
# Processing Record 26 of Set 10 | tromso
# Processing Record 27 of Set 10 | severiano melo
# Processing Record 28 of Set 10 | tahta
# Processing Record 29 of Set 10 | buenos aires
# Processing Record 30 of Set 10 | velikiy ustyug
# Processing Record 31 of Set 10 | gonen
# Processing Record 32 of Set 10 | seredka
# Processing Record 33 of Set 10 | sheltozero
# Processing Record 34 of Set 10 | santo antonio do ica
# Processing Record 35 of Set 10 | sajokaza
# Processing Record 36 of Set 10 | yarmolyntsi
# Processing Record 37 of Set 10 | motupe
# Processing Record 38 of Set 10 | agrafa
# Processing Record 39 of Set 10 | boyabat
# Processing Record 40 of Set 10 | catumbela
# Processing Record 41 of Set 10 | conakry
# Processing Record 42 of Set 10 | urucui
# Processing Record 43 of Set 10 | rio gallegos
# Processing Record 44 of Set 10 | rangpur
# Processing Record 45 of Set 10 | murgab
# Processing Record 46 of Set 10 | santa marta
# Processing Record 47 of Set 10 | supe
# Processing Record 48 of Set 10 | bonfim
# Processing Record 49 of Set 10 | marquard
# Processing Record 50 of Set 10 | suure-jaani
# Processing Record 1 of Set 11 | pangnirtung
# Processing Record 2 of Set 11 | gornopravdinsk
# Processing Record 3 of Set 11 | ariquemes
# Processing Record 4 of Set 11 | oksbol
# Processing Record 5 of Set 11 | qasigiannguit
# Processing Record 6 of Set 11 | ovalle
# Processing Record 7 of Set 11 | timbiqui
# Processing Record 8 of Set 11 | wadi maliz
# Processing Record 9 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 11 | polovinnoye
# Processing Record 11 of Set 11 | eyrarbakki
# Processing Record 12 of Set 11 | asyut
# Processing Record 13 of Set 11 | san juan
# Processing Record 14 of Set 11 | ankazoabo
# Processing Record 15 of Set 11 | skiros
# City not found. Skipping...
# Processing Record 16 of Set 11 | ansalta
# Processing Record 17 of Set 11 | ruwi
# Processing Record 18 of Set 11 | ormara
# Processing Record 19 of Set 11 | pizarro
# Processing Record 20 of Set 11 | saint-louis
# Processing Record 21 of Set 11 | rajanpur
# Processing Record 22 of Set 11 | belmonte
# Processing Record 23 of Set 11 | valenca do piaui
# Processing Record 24 of Set 11 | kuzhener
# Processing Record 25 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 26 of Set 11 | porbandar
# Processing Record 27 of Set 11 | comodoro rivadavia
# Processing Record 28 of Set 11 | jepelacio
# Processing Record 29 of Set 11 | pilao arcado
# City not found. Skipping...
# Processing Record 30 of Set 11 | juba
# Processing Record 31 of Set 11 | truro
# Processing Record 32 of Set 11 | aleksandrov gay
# Processing Record 33 of Set 11 | carballo
# Processing Record 34 of Set 11 | sao raimundo das mangabeiras
# Processing Record 35 of Set 11 | chapais
# Processing Record 36 of Set 11 | jacareacanga
# Processing Record 37 of Set 11 | araouane
# Processing Record 38 of Set 11 | gazli
# Processing Record 39 of Set 11 | eskasem
# City not found. Skipping...
# Processing Record 40 of Set 11 | nacala
# Processing Record 41 of Set 11 | luanda
# Processing Record 42 of Set 11 | loiza
# Processing Record 43 of Set 11 | tacuarembo
# Processing Record 44 of Set 11 | matongo
# Processing Record 45 of Set 11 | lagos
# Processing Record 46 of Set 11 | russkaya polyana
# Processing Record 47 of Set 11 | portlethen
# Processing Record 48 of Set 11 | lucapa
# Processing Record 49 of Set 11 | the valley
# Processing Record 50 of Set 11 | camargo
# Processing Record 1 of Set 12 | negombo
# Processing Record 2 of Set 12 | safaga
# Processing Record 3 of Set 12 | andenes
# Processing Record 4 of Set 12 | maksatikha
# Processing Record 5 of Set 12 | pinheiro machado
# Processing Record 6 of Set 12 | puerto ayora
# Processing Record 7 of Set 12 | sinop
# Processing Record 8 of Set 12 | lubao
# Processing Record 9 of Set 12 | cockburn town
# Processing Record 10 of Set 12 | nouadhibou
# Processing Record 11 of Set 12 | saint albans
# Processing Record 12 of Set 12 | bom jesus
# Processing Record 13 of Set 12 | kermanshah
# Processing Record 14 of Set 12 | golpayegan
# Processing Record 15 of Set 12 | sapele
# Processing Record 16 of Set 12 | nieuw nickerie
# Processing Record 17 of Set 12 | coxim
# Processing Record 18 of Set 12 | novosokolniki
# Processing Record 19 of Set 12 | nova serrana
# Processing Record 20 of Set 12 | aracruz
# Processing Record 21 of Set 12 | cayambe
# Processing Record 22 of Set 12 | tandil
# Processing Record 23 of Set 12 | san bernardo
# Processing Record 24 of Set 12 | shuyskoye
# Processing Record 25 of Set 12 | peciu nou
# Processing Record 26 of Set 12 | hobyo
# Processing Record 27 of Set 12 | wesselsbron
# Processing Record 28 of Set 12 | zaozerne
# Processing Record 29 of Set 12 | sistranda
# Processing Record 30 of Set 12 | labrea
# Processing Record 31 of Set 12 | ayorou
# Processing Record 32 of Set 12 | castelldefels
# Processing Record 33 of Set 12 | boke
# Processing Record 34 of Set 12 | reconquista
# Processing Record 35 of Set 12 | bindura
# Processing Record 36 of Set 12 | vredendal
# Processing Record 37 of Set 12 | nicoya
# Processing Record 38 of Set 12 | balkhash
# Processing Record 39 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 40 of Set 12 | botoroaga
# Processing Record 41 of Set 12 | akonolinga
# Processing Record 42 of Set 12 | miraflores
# Processing Record 43 of Set 12 | wajir
# Processing Record 44 of Set 12 | krasnozerskoye
# Processing Record 45 of Set 12 | mariakani
# Processing Record 46 of Set 12 | aksarka
# Processing Record 47 of Set 12 | channel-port aux basques
# Processing Record 48 of Set 12 | bhavani
# Processing Record 49 of Set 12 | watsa
# Processing Record 50 of Set 12 | westport
# Processing Record 1 of Set 13 | gobabis
# Processing Record 2 of Set 13 | brockville
# Processing Record 3 of Set 13 | komsomolskiy
# Processing Record 4 of Set 13 | ambilobe
# Processing Record 5 of Set 13 | luziania
# Processing Record 6 of Set 13 | mushie
# Processing Record 7 of Set 13 | uige
# Processing Record 8 of Set 13 | burdur
# Processing Record 9 of Set 13 | svodin
# Processing Record 10 of Set 13 | arcachon
# Processing Record 11 of Set 13 | big rapids
# Processing Record 12 of Set 13 | dzaoudzi
# Processing Record 13 of Set 13 | lluta
# Processing Record 14 of Set 13 | umm lajj
# Processing Record 15 of Set 13 | sigerfjord
# City not found. Skipping...
# Processing Record 16 of Set 13 | liverpool
# Processing Record 17 of Set 13 | tauteu
# Processing Record 18 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 19 of Set 13 | menongue
# Processing Record 20 of Set 13 | cayenne
# Processing Record 21 of Set 13 | fossombrone
# Processing Record 22 of Set 13 | leh
# Processing Record 23 of Set 13 | dzhuryn
# Processing Record 24 of Set 13 | kidal
# Processing Record 25 of Set 13 | masuguru
# Processing Record 26 of Set 13 | nesna
# Processing Record 27 of Set 13 | maceio
# Processing Record 28 of Set 13 | asind
# Processing Record 29 of Set 13 | petrovsk
# Processing Record 30 of Set 13 | guabito
# Processing Record 31 of Set 13 | mbanza-ngungu
# Processing Record 32 of Set 13 | youkounkoun
# Processing Record 33 of Set 13 | bayan
# Processing Record 34 of Set 13 | luau
# Processing Record 35 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 36 of Set 13 | marzuq
# Processing Record 37 of Set 13 | gravdal
# Processing Record 38 of Set 13 | kolyvan
# Processing Record 39 of Set 13 | syamzha
# Processing Record 40 of Set 13 | madimba
# Processing Record 41 of Set 13 | mercedes
# Processing Record 42 of Set 13 | domoni
# Processing Record 43 of Set 13 | tiznit
# Processing Record 44 of Set 13 | loharu
# Processing Record 45 of Set 13 | sharjah
# Processing Record 46 of Set 13 | strezhevoy
# Processing Record 47 of Set 13 | sao francisco
# Processing Record 48 of Set 13 | nioro
# Processing Record 49 of Set 13 | morlaix
# Processing Record 50 of Set 13 | jibuti
# Processing Record 1 of Set 14 | stornoway
# Processing Record 2 of Set 14 | hlobyne
# Processing Record 3 of Set 14 | rusape
# Processing Record 4 of Set 14 | ejido
# Processing Record 5 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 7 of Set 14 | bay roberts
# Processing Record 8 of Set 14 | pedras de fogo
# Processing Record 9 of Set 14 | hanko
# Processing Record 10 of Set 14 | neftcala
# Processing Record 11 of Set 14 | harindanga
# Processing Record 12 of Set 14 | nadvoitsy
# Processing Record 13 of Set 14 | luis correia
# Processing Record 14 of Set 14 | devrek
# Processing Record 15 of Set 14 | taoudenni
# Processing Record 16 of Set 14 | chhindwara
# Processing Record 17 of Set 14 | gemena
# Processing Record 18 of Set 14 | abalak
# Processing Record 19 of Set 14 | manica
# Processing Record 20 of Set 14 | calvinia
# Processing Record 21 of Set 14 | lyngseidet
# Processing Record 22 of Set 14 | mahon
# Processing Record 23 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 24 of Set 14 | assisi
# Processing Record 25 of Set 14 | parga
# Processing Record 26 of Set 14 | gaoua
# Processing Record 27 of Set 14 | arandis
# Processing Record 28 of Set 14 | harper
# Processing Record 29 of Set 14 | pakala
# Processing Record 30 of Set 14 | dakar
# Processing Record 31 of Set 14 | zmeinogorsk
# Processing Record 32 of Set 14 | pauini
# Processing Record 33 of Set 14 | itaituba
# Processing Record 34 of Set 14 | amapa
# Processing Record 35 of Set 14 | havelock
# Processing Record 36 of Set 14 | lundazi
# Processing Record 37 of Set 14 | natalio
# Processing Record 38 of Set 14 | dusetos
# Processing Record 39 of Set 14 | puerto maldonado
# Processing Record 40 of Set 14 | mehran
# Processing Record 41 of Set 14 | angoche
# Processing Record 42 of Set 14 | mbour
# Processing Record 43 of Set 14 | guane
# Processing Record 44 of Set 14 | ciudad guayana
# Processing Record 45 of Set 14 | tsabong
# Processing Record 46 of Set 14 | ibra
# Processing Record 47 of Set 14 | saint-augustin
# Processing Record 48 of Set 14 | mutoko
# Processing Record 49 of Set 14 | makokou
# Processing Record 50 of Set 14 | hakvik
# City not found. Skipping...
# Processing Record 1 of Set 15 | shaygino
# Processing Record 2 of Set 15 | ipaba
# Processing Record 3 of Set 15 | tabas
# Processing Record 4 of Set 15 | vestmannaeyjar
# Processing Record 5 of Set 15 | am timan
# Processing Record 6 of Set 15 | cheremukhovo
# Processing Record 7 of Set 15 | preston
# Processing Record 8 of Set 15 | batticaloa
# Processing Record 9 of Set 15 | skelleftea
# Processing Record 10 of Set 15 | hearst
# Processing Record 11 of Set 15 | megion
# Processing Record 12 of Set 15 | bako
# Processing Record 13 of Set 15 | baringo
# Processing Record 14 of Set 15 | colares
# Processing Record 15 of Set 15 | emba
# Processing Record 16 of Set 15 | impfondo
# Processing Record 17 of Set 15 | rincon
# Processing Record 18 of Set 15 | rochester
# Processing Record 19 of Set 15 | staraya poltavka
# Processing Record 20 of Set 15 | arroyo
# Processing Record 21 of Set 15 | talas
# Processing Record 22 of Set 15 | maracaibo
# Processing Record 23 of Set 15 | timizart
# Processing Record 24 of Set 15 | taybad
# Processing Record 25 of Set 15 | meiganga
# Processing Record 26 of Set 15 | sawakin
# Processing Record 27 of Set 15 | zonguldak
# Processing Record 28 of Set 15 | cap malheureux
# Processing Record 29 of Set 15 | utete
# Processing Record 30 of Set 15 | cambridge
# Processing Record 31 of Set 15 | buchanan
# Processing Record 32 of Set 15 | soverato
# Processing Record 33 of Set 15 | whithorn
# Processing Record 34 of Set 15 | himora
# City not found. Skipping...
# Processing Record 35 of Set 15 | paipa
# Processing Record 36 of Set 15 | santa maria
# Processing Record 37 of Set 15 | mumford
# Processing Record 38 of Set 15 | severodvinsk
# Processing Record 39 of Set 15 | altamira
# Processing Record 40 of Set 15 | shache
# Processing Record 41 of Set 15 | dudinka
# Processing Record 42 of Set 15 | kiruna
# Processing Record 43 of Set 15 | kangaatsiaq
# Processing Record 44 of Set 15 | lubango
# Processing Record 45 of Set 15 | nueve de julio
# Processing Record 46 of Set 15 | baoro
# Processing Record 47 of Set 15 | guider
# Processing Record 48 of Set 15 | phalaborwa
# Processing Record 49 of Set 15 | lodwar
# Processing Record 50 of Set 15 | agropoli
# Processing Record 1 of Set 16 | piacabucu
# Processing Record 2 of Set 16 | bestobe
# Processing Record 3 of Set 16 | beboto
# Processing Record 4 of Set 16 | aswan
# Processing Record 5 of Set 16 | sao miguel do iguacu
# Processing Record 6 of Set 16 | loandjili
# Processing Record 7 of Set 16 | benjamin aceval
# Processing Record 8 of Set 16 | haverhill
# Processing Record 9 of Set 16 | voznesenye
# Processing Record 10 of Set 16 | pangody
# Processing Record 11 of Set 16 | skibbereen
# Processing Record 12 of Set 16 | bloemfontein
# Processing Record 13 of Set 16 | tazmalt
# Processing Record 14 of Set 16 | palm coast
# Processing Record 15 of Set 16 | marsh harbour
# Processing Record 16 of Set 16 | boralday
# Processing Record 17 of Set 16 | sangin
# Processing Record 18 of Set 16 | cristalina
# Processing Record 19 of Set 16 | ati
# Processing Record 20 of Set 16 | antofagasta
# Processing Record 21 of Set 16 | mahabad
# Processing Record 22 of Set 16 | eydhafushi
# Processing Record 23 of Set 16 | cozumel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 721

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Souillac -20.5167   57.5167     70.77        73          10
# 1     Bredasdorp -34.5322   20.0403     66.99        74          70
# 2     Bjornevatn  69.6672   29.9847     43.14        87          75
# 3      Carnarvon -24.8667  113.6333     65.48        67           0
# 4  Alta Floresta  -9.8756  -56.0861     96.30        36          79
# 5       Kalmunai   7.4167   81.8167     79.30        85          95
# 6      Busselton -33.6500  115.3333     50.31        88           0
# 7    Henties Bay -22.1160   14.2845     61.52        83           7
# 8          Korla  41.7597   86.1469     56.86        22          48
# 9           Hofn  64.2539  -15.2082     41.02        81          40
#
#    Wind Speed Country
# 0       10.02      MU
# 1       13.67      ZA
# 2        8.05      NO
# 3       25.30      AU
# 4        2.84      BR
# 5        5.37      LK
# 6        7.31      AU
# 7       11.61      NA
# 8        1.95      CN
# 9        4.61      IS

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.dtypes
# Out:
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# dtype: object

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Souillac      MU -20.5167   57.5167     70.77        73          10
# 1     Bredasdorp      ZA -34.5322   20.0403     66.99        74          70
# 2     Bjornevatn      NO  69.6672   29.9847     43.14        87          75
# 3      Carnarvon      AU -24.8667  113.6333     65.48        67           0
# 4  Alta Floresta      BR  -9.8756  -56.0861     96.30        36          79
# 5       Kalmunai      LK   7.4167   81.8167     79.30        85          95
# 6      Busselton      AU -33.6500  115.3333     50.31        88           0
# 7    Henties Bay      NA -22.1160   14.2845     61.52        83           7
# 8          Korla      CN  41.7597   86.1469     56.86        22          48
# 9           Hofn      IS  64.2539  -15.2082     41.02        81          40
#
#    Wind Speed
# 0       10.02
# 1       13.67
# 2        8.05
# 3       25.30
# 4        2.84
# 5        5.37
# 6        7.31
# 7       11.61
# 8        1.95
# 9        4.61

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
